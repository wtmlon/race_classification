# %%
from network.resnet import resnet18

# %%
model = resnet18()

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
from network.res_se_net import se_resnet_18
from network.resnet import resnet18

# %%
import torch
model = se_resnet_18()
model1 = resnet18()
a = torch.FloatTensor(torch.randn([1, 3, 178, 218]))

# %%
model
# Out:
# SENet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (globalAvgPool): AvgPool2d(kernel_size=56, stride=1, padding=0)
#       (fc1): Linear(in_features=64, out_features=4, bias=True)
#       (fc2): Linear(in_features=4, out_features=64, bias=True)
#       (sigmoid): Sigmoid()
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-db90299b906b> in <module>
# ----> 1 out = model(a)
#       2 out
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# /data/home/liuting/Race_Classification/network/res_se_net.py in forward(self, x)
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
# ...

# %%
model1
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# Out:
# tensor([[-0.7445, -0.3360,  0.7443,  0.5647,  0.1859,  0.2345, -0.1078, -0.1355,
#           0.3536, -0.1280, -0.7610,  0.1524, -0.2894,  0.8895, -0.7349, -0.1552,
#           0.0077, -0.9383, -0.4157,  0.1801,  0.9085,  0.1206,  0.1656,  0.1345,
#           0.2266,  0.0121,  0.4952,  0.0195, -1.2773,  0.5945,  0.1874, -0.2314,
#          -0.2614, -0.4037,  0.1693, -0.1377,  0.5887, -0.0130, -0.4445, -0.1368,
#          -0.1927, -0.0303,  0.0270, -0.7604,  0.9148,  0.2635, -0.5795, -1.0520,
#          -0.5002, -0.0042,  0.3569, -0.1998, -0.0840, -0.3007,  0.5003, -0.1739,
#           0.7982, -0.0479, -0.2664, -0.4327,  0.1980,  0.3799,  0.0454, -0.2905,
#           0.6485, -0.1176, -0.9925, -0.0642,  0.5264, -0.5089,  0.0422,  0.4775,
#           0.3668, -0.5341,  0.4025, -0.0626, -0.5572,  0.7214, -0.5622, -0.2265,
#          -0.8971,  0.1737,  0.1460,  0.0582, -0.1422, -0.0555, -0.3737,  0.3118,
#           0.1721,  0.3900, -0.2732,  0.6387,  0.3505,  0.4975,  0.7339, -0.3240,
# ...

# %%
import torch
from network.MobileNetV2 import MobileNetV2
model = MobileNetV2(n_class=3)

# %%
a = torch.FloatTensor(torch.randn([1, 3, 178, 218]))
a.shape
# Out:
# torch.Size([1, 3, 178, 218])

# %%
out = model(a)

# %%
out.shape
# Out:
# torch.Size([1, 3])

# %%
import torch.hub
hub_model = torch.hub.load(
    'moskomule/senet.pytorch',
    'se_resnet20',
    num_classes=10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-696e29bc3658> in <module>
# ----> 1 import torch.hub
#       2 hub_model = torch.hub.load(
#       3     'moskomule/senet.pytorch',
#       4     'se_resnet20',
#       5     num_classes=10)
#
# ImportError: No module named 'torch.hub'

# %%
from network.senet.se_resnet import se_resnet50
model = se_resnet50(num_classes=3, pretrained=True)
# Out:
# Downloading: "https://www.dropbox.com/s/xpq8ne7rwa4kg4c/seresnet50-60a8950a85b2b.pkl" to /home/liuting/.torch/models/seresnet50-60a8950a85b2b.pkl
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# ...

# %%
print(model)

# %%
import torchvision.models as models
resnet1 = models.inception_v3()
num_ftrs = resnet1.fc.in_features
resnet1.fc = nn.Linear(num_ftrs, 3, bais=True)
print(resnet1)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
# ...

# %%
print(resnet1.classifier[1].out_channels)
# Out:
# 1000
